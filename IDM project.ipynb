# %%
#importing pandas and loading dataset into dataframe
import pandas as pd

df = pd.read_csv('data.csv')
df.head()
# Out:
#    valence  year  acousticness  \
# 0   0.0594  1921         0.982
# 1   0.9630  1921         0.732
# 2   0.0394  1921         0.961
# 3   0.1650  1921         0.967
# 4   0.2530  1921         0.957
#
#                                              artists  danceability  \
# 0  ['Sergei Rachmaninoff', 'James Levine', 'Berli...         0.279
# 1                                     ['Dennis Day']         0.819
# 2  ['KHP Kridhamardawa Karaton Ngayogyakarta Hadi...         0.328
# 3                                   ['Frank Parker']         0.275
# 4                                     ['Phil Regan']         0.418
#
#    duration_ms  energy  explicit                      id  instrumentalness  \
# 0       831667   0.211         0  4BJqT0PrAfrxzMOxytFOIz          0.878000
# 1       180533   0.341         0  7xPhfUan2yNtyFG0cUWkt8          0.000000
# 2       500062   0.166         0  1o6I8BglA6ylDMrIELygv1          0.913000
# 3       210000   0.309         0  3ftBPsC5vPBKxYSee08FDH          0.000028
# 4       166693   0.193         0  4d6HGyGT8e121BsdKmw9v6          0.000002
#
#    key  liveness  loudness  mode  \
# 0   10     0.665   -20.096     1
# 1    7     0.160   -12.441     1
# 2    3     0.101   -14.850     1
# 3    5     0.381    -9.316     1
# 4    3     0.229   -10.096     1
#
#                                                 name  popularity release_date  \
# 0  Piano Concerto No. 3 in D Minor, Op. 30: III. ...           4         1921
# 1                            Clancy Lowered the Boom           5         1921
# 2                                          Gati Bali           5         1921
# 3                                          Danny Boy           3         1921
# 4                        When Irish Eyes Are Smiling           2         1921
#
#    speechiness    tempo
# 0       0.0366   80.954
# 1       0.4150   60.936
# 2       0.0339  110.339
# 3       0.0354  100.109
# 4       0.0380  101.665

# %%
df.describe()
# Out:
#              valence           year   acousticness   danceability  \
# count  170653.000000  170653.000000  170653.000000  170653.000000
# mean        0.528587    1976.787241       0.502115       0.537396
# std         0.263171      25.917853       0.376032       0.176138
# min         0.000000    1921.000000       0.000000       0.000000
# 25%         0.317000    1956.000000       0.102000       0.415000
# 50%         0.540000    1977.000000       0.516000       0.548000
# 75%         0.747000    1999.000000       0.893000       0.668000
# max         1.000000    2020.000000       0.996000       0.988000
#
#         duration_ms         energy       explicit  instrumentalness  \
# count  1.706530e+05  170653.000000  170653.000000     170653.000000
# mean   2.309483e+05       0.482389       0.084575          0.167010
# std    1.261184e+05       0.267646       0.278249          0.313475
# min    5.108000e+03       0.000000       0.000000          0.000000
# 25%    1.698270e+05       0.255000       0.000000          0.000000
# 50%    2.074670e+05       0.471000       0.000000          0.000216
# 75%    2.624000e+05       0.703000       0.000000          0.102000
# max    5.403500e+06       1.000000       1.000000          1.000000
#
#                  key       liveness       loudness           mode  \
# count  170653.000000  170653.000000  170653.000000  170653.000000
# mean        5.199844       0.205839     -11.467990       0.706902
# std         3.515094       0.174805       5.697943       0.455184
# min         0.000000       0.000000     -60.000000       0.000000
# 25%         2.000000       0.098800     -14.615000       0.000000
# 50%         5.000000       0.136000     -10.580000       1.000000
# 75%         8.000000       0.261000      -7.183000       1.000000
# max        11.000000       1.000000       3.855000       1.000000
#
#           popularity    speechiness          tempo
# count  170653.000000  170653.000000  170653.000000
# mean       31.431794       0.098393     116.861590
# std        21.826615       0.162740      30.708533
# min         0.000000       0.000000       0.000000
# 25%        11.000000       0.034900      93.421000
# 50%        33.000000       0.045000     114.729000
# 75%        48.000000       0.075600     135.537000
# max       100.000000       0.970000     243.507000

# %%
df.shape
# Out:
# (170653, 19)

# %%
#checking for missing value
df.isnull()
# Out:
#         valence   year  acousticness  artists  danceability  duration_ms  \
# 0         False  False         False    False         False        False
# 1         False  False         False    False         False        False
# 2         False  False         False    False         False        False
# 3         False  False         False    False         False        False
# 4         False  False         False    False         False        False
# ...         ...    ...           ...      ...           ...          ...
# 170648    False  False         False    False         False        False
# 170649    False  False         False    False         False        False
# 170650    False  False         False    False         False        False
# 170651    False  False         False    False         False        False
# 170652    False  False         False    False         False        False
#
#         energy  explicit     id  instrumentalness    key  liveness  loudness  \
# 0        False     False  False             False  False     False     False
# 1        False     False  False             False  False     False     False
# 2        False     False  False             False  False     False     False
# 3        False     False  False             False  False     False     False
# 4        False     False  False             False  False     False     False
# ...        ...       ...    ...               ...    ...       ...       ...
# 170648   False     False  False             False  False     False     False
# 170649   False     False  False             False  False     False     False
# 170650   False     False  False             False  False     False     False
# 170651   False     False  False             False  False     False     False
# 170652   False     False  False             False  False     False     False
#
#          mode   name  popularity  release_date  speechiness  tempo
# 0       False  False       False         False        False  False
# 1       False  False       False         False        False  False
# 2       False  False       False         False        False  False
# 3       False  False       False         False        False  False
# 4       False  False       False         False        False  False
# ...       ...    ...         ...           ...          ...    ...
# 170648  False  False       False         False        False  False
# 170649  False  False       False         False        False  False
# 170650  False  False       False         False        False  False
# 170651  False  False       False         False        False  False
# 170652  False  False       False         False        False  False
#
# [170653 rows x 19 columns]

# %%
df.isna().any().any()
# Out:
# False

# %%
# no missing value found
df.isnull().values.any()
# Out:
# False

# %%
#generating graphs for the variables to visually interpret the variable distribution in dataset
ax = df['valence'].value_counts(bins=20).sort_index().plot.bar()
ax.set_xlabel("valence")
ax.set_ylabel("count")
ax.set_title("valence distribution")
# Out:
# Text(0.5, 1.0, 'valence distribution')

# %%
# generating correlation matrix using pearson correlation coefficient.
# year and popularity are found to be highly correlated
# energy and loudness are also highly correlated
corr = df.corr()
corr.style.background_gradient(cmap='coolwarm').set_precision(2)
# Out:
# <style  type="text/css" >
#     #T_c161daf8_534b_11eb_b726_8c85903d9d98row0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_c161daf8_534b_11eb_b726_8c85903d9d98row0_col1 {
#             background-color:  #b3cdfb;
#             color:  #000000;
#         }    #T_c161daf8_534b_11eb_b726_8c85903d9d98row0_col2 {
#             background-color:  #a6c4fe;
#             color:  #000000;
#         }    #T_c161daf8_534b_11eb_b726_8c85903d9d98row0_col3 {
#             background-color:  #f7bca1;
#             color:  #000000;
#         }    #T_c161daf8_534b_11eb_b726_8c85903d9d98row0_col4 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_c161daf8_534b_11eb_b726_8c85903d9d98row0_col5 {
#             background-color:  #f5c2aa;
#             color:  #000000;
#         }    #T_c161daf8_534b_11eb_b726_8c85903d9d98row0_col6 {
#             background-color:  #7597f6;
#             color:  #000000;
#         }    #T_c161daf8_534b_11eb_b726_8c85903d9d98row0_col7 {
#             background-color:  #6a8bef;
#             color:  #000000;
#         }    #T_c161daf8_534b_11eb_b726_8c85903d9d98row0_col8 {
#             background-color:  #6384eb;
#             color:  #000000;
#         }    #T_c161daf8_534b_11eb_b726_8c85903d9d98row0_col9 {
#             background-color:  #5875e1;
#             color:  #000000;
#         }    #T_c161daf8_534b_11eb_b726_8c85903d9d98row0_col10 {
#             background-color:  #ebd3c6;
#             color:  #000000;
#         }    #T_c161daf8_534b_11eb_b726_8c85903d9d98row0_col11 {
#             background-color:  #5f7fe8;
#             color:  #000000;
#         }    #T_c161daf8_534b_11eb_b726_8c85903d9d98row0_col12 {
#             background-color:  #b7cff9;
#             color:  #000000;
#         }    #T_c161daf8_534b_11eb_b726_8c85903d9d98row0_col13 {
#             background-color:  #7699f6;
#             color:  #000000;
#         }    #T_c161daf8_534b_11eb_b726_8c85903d9d98row0_col14 {
#             background-color:  #a3c2fe;
#             color:  #000000;
#         }    #T_c161daf8_534b_11eb_b726_8c85903d9d98row1_col0 {
#             background-color:  #6788ee;
#             color:  #000000;
#         }    #T_c161daf8_534b_11eb_b726_8c85903d9d98row1_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_c161daf8_534b_11eb_b726_8c85903d9d98row1_col2 {
#             background-color:  #516ddb;
#             color:  #000000;
#         }    #T_c161daf8_534b_11eb_b726_8c85903d9d98row1_col3 {
#             background-color:  #b5cdfa;
#             color:  #000000;
#         }    #T_c161daf8_534b_11eb_b726_8c85903d9d98row1_col4 {
#             background-color:  #85a8fc;
#             color:  #000000;
#         }    #T_c161daf8_534b_11eb_b726_8c85903d9d98row1_col5 {
#             background-color:  #f5a081;
#             color:  #000000;
#         }    #T_c161daf8_534b_11eb_b726_8c85903d9d98row1_col6 {
#             background-color:  #b7cff9;
#             color:  #000000;
#         }    #T_c161daf8_534b_11eb_b726_8c85903d9d98row1_col7 {
#             background-color:  #5875e1;
#             color:  #000000;
#         }    #T_c161daf8_534b_11eb_b726_8c85903d9d98row1_col8 {
#             background-color:  #5d7ce6;
#             color:  #000000;
#         }    #T_c161daf8_534b_11eb_b726_8c85903d9d98row1_col9 {
#             background-color:  #455cce;
#             color:  #f1f1f1;
#         }    #T_c161daf8_534b_11eb_b726_8c85903d9d98row1_col10 {
#             background-color:  #f7b599;
#             color:  #000000;
#         }    #T_c161daf8_534b_11eb_b726_8c85903d9d98row1_col11 {
#             background-color:  #516ddb;
#             color:  #000000;
#         }    #T_c161daf8_534b_11eb_b726_8c85903d9d98row1_col12 {
#             background-color:  #d24b40;
#             color:  #f1f1f1;
#         }    #T_c161daf8_534b_11eb_b726_8c85903d9d98row1_col13 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_c161daf8_534b_11eb_b726_8c85903d9d98row1_col14 {
#             background-color:  #9abbff;
#             color:  #000000;
#         }    #T_c161daf8_534b_11eb_b726_8c85903d9d98row2_col0 {
#             background-color:  #3e51c5;
#             color:  #f1f1f1;
#         }    #T_c161daf8_534b_11eb_b726_8c85903d9d98row2_col1 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_c161daf8_534b_11eb_b726_8c85903d9d98row2_col2 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_c161daf8_534b_11eb_b726_8c85903d9d98row2_col3 {
#             background-color:  #3d50c3;
#             color:  #f1f1f1;
#         }    #T_c161daf8_534b_11eb_b726_8c85903d9d98row2_col4 {
#             background-color:  #5875e1;
#             color:  #000000;
#         }    #T_c161daf8_534b_11eb_b726_8c85903d9d98row2_col5 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_c161daf8_534b_11eb_b726_8c85903d9d98row2_col6 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_c161daf8_534b_11eb_b726_8c85903d9d98row2_col7 {
#             background-color:  #e3d9d3;
#             color:  #000000;
#         }    #T_c161daf8_534b_11eb_b726_8c85903d9d98row2_col8 {
#             background-color:  #5470de;
#             color:  #000000;
#         }    #T_c161daf8_534b_11eb_b726_8c85903d9d98row2_col9 {
#             background-color:  #4f69d9;
#             color:  #000000;
#         }    #T_c161daf8_534b_11eb_b726_8c85903d9d98row2_col10 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_c161daf8_534b_11eb_b726_8c85903d9d98row2_col11 {
#             background-color:  #688aef;
#             color:  #000000;
#         }    #T_c161daf8_534b_11eb_b726_8c85903d9d98row2_col12 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_c161daf8_534b_11eb_b726_8c85903d9d98row2_col13 {
#             background-color:  #5b7ae5;
#             color:  #000000;
#         }    #T_c161daf8_534b_11eb_b726_8c85903d9d98row2_col14 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_c161daf8_534b_11eb_b726_8c85903d9d98row3_col0 {
#             background-color:  #f5c2aa;
#             color:  #000000;
#         }    #T_c161daf8_534b_11eb_b726_8c85903d9d98row3_col1 {
#             background-color:  #dcdddd;
#             color:  #000000;
#         }    #T_c161daf8_534b_11eb_b726_8c85903d9d98row3_col2 {
#             background-color:  #96b7ff;
#             color:  #000000;
#         }    #T_c161daf8_534b_11eb_b726_8c85903d9d98row3_col3 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_c161daf8_534b_11eb_b726_8c85903d9d98row3_col4 {
#             background-color:  #485fd1;
#             color:  #f1f1f1;
#         }    #T_c161daf8_534b_11eb_b726_8c85903d9d98row3_col5 {
#             background-color:  #ead4c8;
#             color:  #000000;
#         }    #T_c161daf8_534b_11eb_b726_8c85903d9d98row3_col6 {
#             background-color:  #bed2f6;
#             color:  #000000;
#         }    #T_c161daf8_534b_11eb_b726_8c85903d9d98row3_col7 {
#             background-color:  #5673e0;
#             color:  #000000;
#         }    #T_c161daf8_534b_11eb_b726_8c85903d9d98row3_col8 {
#             background-color:  #6282ea;
#             color:  #000000;
#         }    #T_c161daf8_534b_11eb_b726_8c85903d9d98row3_col9 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_c161daf8_534b_11eb_b726_8c85903d9d98row3_col10 {
#             background-color:  #e7d7ce;
#             color:  #000000;
#         }    #T_c161daf8_534b_11eb_b726_8c85903d9d98row3_col11 {
#             background-color:  #4e68d8;
#             color:  #000000;
#         }    #T_c161daf8_534b_11eb_b726_8c85903d9d98row3_col12 {
#             background-color:  #dadce0;
#             color:  #000000;
#         }    #T_c161daf8_534b_11eb_b726_8c85903d9d98row3_col13 {
#             background-color:  #afcafc;
#             color:  #000000;
#         }    #T_c161daf8_534b_11eb_b726_8c85903d9d98row3_col14 {
#             background-color:  #7295f4;

# %%
# visualizing relationship between loudness and energy using scatter plot
# doing random sampling of 1000 points otherwise the issue of overplotting arises as there are alot of points
import matplotlib.pyplot as plt
df_sample=df.sample(1000)
plt.plot( 'energy', 'loudness', data=df_sample , linestyle='', marker='o', markersize=1,  color="purple")
plt.xlabel('energy')
plt.ylabel('loudness')
plt.title('loudness vs energy scatter plot', loc='left')
# Out:
# Text(0.0, 1.0, 'loudness vs energy scatter plot')

# %%
# visualizing relationship between year and popularity using scatter plot
df_sample=df.sample(1000)
plt.plot( 'year', 'popularity', data=df_sample , linestyle='', marker='o', markersize=1,  color="purple")
plt.xlabel('year')
plt.ylabel('popularity')
plt.title('year vs popularity scatter plot', loc='left')
# Out:
# Text(0.0, 1.0, 'year vs popularity scatter plot')

# %%
# normalizing data 
from sklearn import preprocessing
df2 = df
df2 = df2.drop(columns='name')
df2 = df2.drop(columns='artists')
df2 = df2.drop(columns='id')
df2 = df2.drop(columns='release_date')
x = df2.values
min_max_scaler = preprocessing.MinMaxScaler()
x_scaled = min_max_scaler.fit_transform(x)
df2 = pd.DataFrame(x_scaled,columns=df2.columns)
print(df2)
# Out:
#         valence  year  acousticness  danceability  duration_ms  energy  \
# 0        0.0594   0.0      0.985944      0.282389     0.153112   0.211
# 1        0.9630   0.0      0.734940      0.828947     0.032496   0.341
# 2        0.0394   0.0      0.964859      0.331984     0.091685   0.166
# 3        0.1650   0.0      0.970884      0.278340     0.037954   0.309
# 4        0.2530   0.0      0.960843      0.423077     0.029932   0.193
# ...         ...   ...           ...           ...          ...     ...
# 170648   0.6080   1.0      0.084940      0.795547     0.054943   0.808
# 170649   0.7340   1.0      0.206827      0.725709     0.026961   0.753
# 170650   0.6370   1.0      0.101406      0.641700     0.038191   0.858
# 170651   0.1950   1.0      0.010020      0.679150     0.061507   0.623
# 170652   0.6420   1.0      0.132530      0.866397     0.034158   0.721
#
#         explicit  instrumentalness       key  liveness  loudness  mode  \
# 0            0.0          0.878000  0.909091    0.6650  0.624916   1.0
# 1            0.0          0.000000  0.636364    0.1600  0.744797   1.0
# 2            0.0          0.913000  0.272727    0.1010  0.707071   1.0
# 3            0.0          0.000028  0.454545    0.3810  0.793736   1.0
# 4            0.0          0.000002  0.272727    0.2290  0.781521   1.0
# ...          ...               ...       ...       ...       ...   ...
# 170648       0.0          0.000289  0.636364    0.0822  0.881654   1.0
# 170649       0.0          0.000000  0.636364    0.1010  0.845353   1.0
# 170650       0.0          0.000009  0.363636    0.2580  0.904769   0.0
# 170651       1.0          0.000008  0.181818    0.6430  0.827484   1.0
# 170652       1.0          0.004710  0.636364    0.1820  0.862454   1.0
#
#         popularity  speechiness     tempo
# 0             0.04     0.037732  0.332450
# 1             0.05     0.427835  0.250243
# 2             0.05     0.034948  0.453125
# 3             0.03     0.036495  0.411113
# 4             0.02     0.039175  0.417503
# ...            ...          ...       ...
# 170648        0.72     0.090825  0.431318
# 170649        0.68     0.062371  0.566456
# 170650        0.76     0.083402  0.376531
# 170651        0.70     0.317526  0.308225
# 170652        0.74     0.111340  0.390096
#
# [170653 rows x 15 columns]

# %%
# calculating varience of each numeric feature after normalizing
# song duration and loudness are found to have very low varience
df2.var()
# Out:
# valence             0.069259
# year                0.068537
# acousticness        0.142538
# danceability        0.031783
# duration_ms         0.000546
# energy              0.071634
# explicit            0.077423
# instrumentalness    0.098266
# key                 0.102115
# liveness            0.030557
# loudness            0.007962
# mode                0.207193
# popularity          0.047640
# speechiness         0.028148
# tempo               0.015904
# dtype: float64

# %%
# generating box plots for numeric variables to check for univariate outliers
ax = df.boxplot(column=['energy'])
ax.set_title("box plots")
# Out:
# Text(0.5, 1.0, 'box plots')

# %%
# generating lower quartile, upper quartile and inter quartile range for each numeric variable in dataset.
Q1 = df.quantile(0.25)
Q3 = df.quantile(0.75)
IQR = Q3 - Q1
print(IQR)
# Out:
# valence                 0.4300
# year                   43.0000
# acousticness            0.7910
# danceability            0.2530
# duration_ms         92573.0000
# energy                  0.4480
# explicit                0.0000
# instrumentalness        0.1020
# key                     6.0000
# liveness                0.1622
# loudness                7.4320
# mode                    1.0000
# popularity             37.0000
# speechiness             0.0407
# tempo                  42.1160
# dtype: float64

# %%
# for numeric outlier removal interquartile range multiplier(k) is set at 1.5
dfx = df[~((df < (Q1 - 1.5 * IQR)) |(df > (Q3 + 1.5 * IQR))).any(axis=1)]
dfx.shape
# Out:
# (96374, 19)

# %%
# dfx is our training data frame
# we remove unnecessary features
# year and loudness are removed because they are highly correlated with other features
# duration is removed because it has very low varience
# artist and song name are unnecessary features
index = dfx['id']
dfx = dfx.drop(columns=['artists','name','release_date','year','loudness','duration_ms','id'],axis=1)

# %%
# normalized data for KNN so that every feature plays an equal role
x = dfx.values
min_max_scaler = preprocessing.MinMaxScaler()
x_scaled = min_max_scaler.fit_transform(x)
dfx = pd.DataFrame(x_scaled,columns=dfx.columns)
dfx.head()
# Out:
#     valence  acousticness  danceability    energy  explicit  instrumentalness  \
# 0  0.164992      0.970883      0.231267  0.307903       0.0          0.000109
# 1  0.252993      0.960843      0.385445  0.191550       0.0          0.000007
# 2  0.195992      0.581325      0.686253  0.345015       0.0          0.658824
# 3  0.405994      1.000000      0.493261  0.201581       0.0          0.000000
# 4  0.720997      1.000000      0.457682  0.128359       0.0          0.592157
#
#         key  liveness  mode  popularity  speechiness     tempo
# 0  0.454545  0.750962   1.0    0.030928     0.115215  0.412301
# 1  0.272727  0.443207   1.0    0.020619     0.138083  0.421576
# 2  0.181818  0.242762   1.0    0.061856     0.419525  0.529827
# 3  0.000000  0.212391   1.0    0.041237     0.344767  0.210284
# 4  0.454545  0.190119   0.0    0.000000     0.228672  0.201086

# %%
# importing KNN 
from sklearn.neighbors import NearestNeighbors
from scipy.sparse import csr_matrix
dfx.index = index
dfx.head()
# Out:
#                          valence  acousticness  danceability    energy  \
# id
# 3ftBPsC5vPBKxYSee08FDH  0.164992      0.970883      0.231267  0.307903
# 4d6HGyGT8e121BsdKmw9v6  0.252993      0.960843      0.385445  0.191550
# 4pyw9DVHGStUre4J6hPngr  0.195992      0.581325      0.686253  0.345015
# 5uNZnElqOS3W4fRmRYPk4T  0.405994      1.000000      0.493261  0.201581
# 05xDjWH9ub67nJJk82yfGf  0.720997      1.000000      0.457682  0.128359
#
#                         explicit  instrumentalness       key  liveness  mode  \
# id
# 3ftBPsC5vPBKxYSee08FDH       0.0          0.000109  0.454545  0.750962   1.0
# 4d6HGyGT8e121BsdKmw9v6       0.0          0.000007  0.272727  0.443207   1.0
# 4pyw9DVHGStUre4J6hPngr       0.0          0.658824  0.181818  0.242762   1.0
# 5uNZnElqOS3W4fRmRYPk4T       0.0          0.000000  0.000000  0.212391   1.0
# 05xDjWH9ub67nJJk82yfGf       0.0          0.592157  0.454545  0.190119   0.0
#
#                         popularity  speechiness     tempo
# id
# 3ftBPsC5vPBKxYSee08FDH    0.030928     0.115215  0.412301
# 4d6HGyGT8e121BsdKmw9v6    0.020619     0.138083  0.421576
# 4pyw9DVHGStUre4J6hPngr    0.061856     0.419525  0.529827
# 5uNZnElqOS3W4fRmRYPk4T    0.041237     0.344767  0.210284
# 05xDjWH9ub67nJJk82yfGf    0.000000     0.228672  0.201086

# %%
# k choosed to be 20 
# model_knn = NearestNeighbors(algorithm='kd_tree',n_neighbors=20)
import numpy as np

 #weighted KNN
weights = np.random.choice(dfx.shape[1])
model_knn = NearestNeighbors(algorithm='brute',metric='wminkowski',metric_params={'w': weights}, p=2, n_jobs=-1)


mat_songs = csr_matrix(dfx.values)

# %%
# model training
model_knn.fit(dfx.values)
# Out:
# NearestNeighbors(algorithm='brute', metric='wminkowski',
#                  metric_params={'w': 11}, n_jobs=-1)

# %%
# recommending songs
def recommend(idx, model, number_of_recommendations=5):
    query = dfx.loc[idx].to_numpy().reshape(1,-1)
    print('Searching for recommendations...')
    distances, indices = model.kneighbors(query,n_neighbors = number_of_recommendations)
    print(distances+indices)
    
    
    for i in indices:
        print(df[['name','artists']].loc[i].where(df['id']!=idx).dropna())

# %%
#Tester

name = input('Enter song title: ')
print('Search results: ')
print(df[['artists','name']].where(df['name'] == name).dropna())

ind = int(input('Enter the index value of the required song: '))
idx = df['id'].loc[ind]

song = df['name'].loc[ind]
artists = df['artists'].loc[ind]

print('Song selected is ', song, 'by', artists)

nor = int(input('Enter number of recommendations: '))

recommend(idx, model_knn, nor)
# Out:
# Enter song title: Snuff
# Search results:
#              artists   name
# 17342   ['Slipknot']  Snuff
# 54837   ['Slipknot']  Snuff
# 153182  ['Slipknot']  Snuff
# Enter the index value of the required song: 17342
# Song selected is  Snuff by ['Slipknot']
# Enter number of recommendations: 5
# Searching for recommendations...
# [[68811. 57830. 70378. 51515. 66067.]]
#                    name               artists
# 68811    2 Hard Mutha's  ['Eazy-E', 'MC Ren']
# 57830  When You Love Me    ['Memphis Minnie']
# 70378             Smile         ['Pearl Jam']
# 51515         La Puerta       ['Luis Miguel']
# 66067   The Necromancer              ['Rush']
